# %%
# File handling = important for any web application
# functions for creating, reading, appending and deleting

# Syntax => open(filename, mode)

# %%
# %%writefile myfile.txt
# Hello this is a text file
# This is a second text line
# This is a third line
# Out:
# Writing myfile.txt

# %%
ls myfile.txt #show all files and directories
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is D213-E0D8
#
#  Directory of C:\Users\Multimedia\OneDrive\Desktop\Python Programs CodeForge
#
#
#  Directory of C:\Users\Multimedia\OneDrive\Desktop\Python Programs CodeForge
#
#
#  Directory of C:\Users\Multimedia\OneDrive\Desktop\Python Programs CodeForge
#
#
#  Directory of C:\Users\Multimedia\OneDrive\Desktop\Python Programs CodeForge
#
#
#  Directory of C:\Users\Multimedia\OneDrive\Desktop\Python Programs CodeForge
#
#
#  Directory of C:\Users\Multimedia\OneDrive\Desktop\Python Programs CodeForge
#
# 15-03-2026  16:52                77 myfile.txt
#                1 File(s)             77 bytes
#                0 Dir(s)  12,088,422,400 bytes free

# %%
pwd  # Present Working Directory = in which directory we currently work in
# Out:
# 'C:\\Users\\Multimedia\\OneDrive\\Desktop\\Python Programs CodeForge'

# %%
my_file = open('myfile.txt','r')

# %%
my_file.read()
# Out:
# 'Hello this is a text file\nThis is a second text line\nThis is a third line\n'

# %%
my_file.close()

# %%
# Using with statement
with open('myfile.txt') as my_new_file:
    content = my_new_file.read()

print(content)
# Out:
# Hello this is a text file
# This is a second text line
# This is a third line

# %%
readLine = open('myfile.txt','r')
print(readLine.readline())  # read only one line
# Out:
# Hello this is a text file

# %%
# reading 5 characters
readLine.read(5)  # read only 5 characters
# Out:
# 'This '

# %%
readLine.close()

# %%
# Writing in the file overwrite the existing file

with open('myfile.txt','w') as f:
    f.write("This is my another text file")

# %%
my_file = open('myfile.txt')
my_file.read()
my_file.close()

# %%
# create a new file using x mode

f = open('my_new_file.txt','x')  # This error occure due to file already exists

# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is D213-E0D8
#
#  Directory of C:\Users\Multimedia\OneDrive\Desktop\Python Programs CodeForge
#
# 15-03-2026  17:14    <DIR>          .
# 15-03-2026  11:33    <DIR>          ..
# 15-03-2026  16:50    <DIR>          .ipynb_checkpoints
# 12-03-2026  20:09             6,325 Array.ipynb
# 12-03-2026  08:41             7,108 BasicPrograms.ipynb
# 15-03-2026  16:21             3,945 Boolean Data Type.ipynb
# 11-03-2026  17:43           354,635 car_dataset.csv
# 08-03-2026  12:04             3,467 ConditionalStatement.ipynb
# 08-03-2026  11:42             4,772 DataType.ipynb
# 09-03-2026  20:24             5,181 Dictionary.ipynb
# 15-03-2026  16:17            10,658 DictionaryMethod.ipynb
# 15-03-2026  17:13             6,267 FileHandling and Operations.ipynb
# 11-03-2026  09:11             2,329 Functions.ipynb
# 13-03-2026  21:00             7,517 ListMethods.ipynb
# 09-03-2026  09:36            13,633 ListOperations.ipynb
# ...

# %%
f.write("This is my_new_file")  # Not perform operation on closed file
# Out:
# 19

# %%
f.close()

# %%
with open('my_new_file.txt') as a:
   data = a.read()

len(data)
# Out:
# 19

# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is D213-E0D8
#
#  Directory of C:\Users\Multimedia\OneDrive\Desktop\Python Programs CodeForge
#
# 15-03-2026  17:38    <DIR>          .
# 15-03-2026  11:33    <DIR>          ..
# 15-03-2026  16:50    <DIR>          .ipynb_checkpoints
# 12-03-2026  20:09             6,325 Array.ipynb
# 12-03-2026  08:41             7,108 BasicPrograms.ipynb
# 15-03-2026  16:21             3,945 Boolean Data Type.ipynb
# 11-03-2026  17:43           354,635 car_dataset.csv
# 08-03-2026  12:04             3,467 ConditionalStatement.ipynb
# 08-03-2026  11:42             4,772 DataType.ipynb
# 09-03-2026  20:24             5,181 Dictionary.ipynb
# 15-03-2026  16:17            10,658 DictionaryMethod.ipynb
# 15-03-2026  17:37            26,209 FileHandling and Operations.ipynb
# 11-03-2026  09:11             2,329 Functions.ipynb
# 13-03-2026  21:00             7,517 ListMethods.ipynb
# 09-03-2026  09:36            13,633 ListOperations.ipynb
# ...

# %%
import os

# %%
os.remove('my_new_file.txt')

# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is D213-E0D8
#
#  Directory of C:\Users\Multimedia\OneDrive\Desktop\Python Programs CodeForge
#
# 15-03-2026  17:38    <DIR>          .
# 15-03-2026  11:33    <DIR>          ..
# 15-03-2026  16:50    <DIR>          .ipynb_checkpoints
# 12-03-2026  20:09             6,325 Array.ipynb
# 12-03-2026  08:41             7,108 BasicPrograms.ipynb
# 15-03-2026  16:21             3,945 Boolean Data Type.ipynb
# 11-03-2026  17:43           354,635 car_dataset.csv
# 08-03-2026  12:04             3,467 ConditionalStatement.ipynb
# 08-03-2026  11:42             4,772 DataType.ipynb
# 09-03-2026  20:24             5,181 Dictionary.ipynb
# 15-03-2026  16:17            10,658 DictionaryMethod.ipynb
# 15-03-2026  17:37            26,209 FileHandling and Operations.ipynb
# 11-03-2026  09:11             2,329 Functions.ipynb
# 13-03-2026  21:00             7,517 ListMethods.ipynb
# 09-03-2026  09:36            13,633 ListOperations.ipynb
# ...

# %%
# create a new file using mode 'r+' = reading and writing = it need file is already exists
file1 = open('myfile.txt','r+')

# %%
file1.read()
# Out:
# 'This is my another text fileThis is PratiikThis is Pratiik'

# %%
file1.seek(0)
# Out:
# 0

# %%
file1.read()
# Out:
# 'This is my another text fileThis is PratiikThis is Pratiik'

# %%
file1.write("This is Pratiik")
# Out:
# 15

# %%
file1.read()
# Out:
# ''

# %%
file1.close()

# %%
file1 = open('myfile.txt','r+')

# %%
file1.read()
# Out:
# 'This is my another text fileThis is PratiikThis is PratiikThis is Pratiik'

# %%
file1.seek(1)  # move a cursor position on specific position in the file
# Out:
# 1

# %%
file1.read()
# Out:
# 'his is my another text fileThis is PratiikThis is PratiikThis is Pratiik'

# %%
file1.close()

# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is D213-E0D8
#
#  Directory of C:\Users\Multimedia\OneDrive\Desktop\Python Programs CodeForge
#
# 15-03-2026  17:38    <DIR>          .
# 15-03-2026  11:33    <DIR>          ..
# 15-03-2026  16:50    <DIR>          .ipynb_checkpoints
# 12-03-2026  20:09             6,325 Array.ipynb
# 12-03-2026  08:41             7,108 BasicPrograms.ipynb
# 15-03-2026  16:21             3,945 Boolean Data Type.ipynb
# 11-03-2026  17:43           354,635 car_dataset.csv
# 08-03-2026  12:04             3,467 ConditionalStatement.ipynb
# 08-03-2026  11:42             4,772 DataType.ipynb
# 09-03-2026  20:24             5,181 Dictionary.ipynb
# 15-03-2026  16:17            10,658 DictionaryMethod.ipynb
# 15-03-2026  17:37            26,209 FileHandling and Operations.ipynb
# 11-03-2026  09:11             2,329 Functions.ipynb
# 13-03-2026  21:00             7,517 ListMethods.ipynb
# 09-03-2026  09:36            13,633 ListOperations.ipynb
# ...

# %%
# to remove file we want to import os module
import os
if os.path.exists('myfile.txt'):
    os.remove('myfile.txt')
else:
    print("File not exists")
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[149], line 4
#       2 import os
#       3 if os.path.exists('myfile.txt'):
# ----> 4     os.remove('myfile.txt')
#       5 else:
#       6     print("File not exists")
#
# PermissionError: [WinError 32] The process cannot access the file because it is being used by another process: 'myfile.txt'

# %%
pwd  # return present working directory
# Out:
# 'C:\\Users\\Multimedia\\OneDrive\\Desktop\\Python Programs CodeForge'

# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is D213-E0D8
#
#  Directory of C:\Users\Multimedia\OneDrive\Desktop\Python Programs CodeForge
#
# 15-03-2026  17:39    <DIR>          .
# 15-03-2026  11:33    <DIR>          ..
# 15-03-2026  16:50    <DIR>          .ipynb_checkpoints
# 12-03-2026  20:09             6,325 Array.ipynb
# 12-03-2026  08:41             7,108 BasicPrograms.ipynb
# 15-03-2026  16:21             3,945 Boolean Data Type.ipynb
# 11-03-2026  17:43           354,635 car_dataset.csv
# 08-03-2026  12:04             3,467 ConditionalStatement.ipynb
# 08-03-2026  11:42             4,772 DataType.ipynb
# 09-03-2026  20:24             5,181 Dictionary.ipynb
# 15-03-2026  16:17            10,658 DictionaryMethod.ipynb
# 15-03-2026  17:39            23,399 FileHandling and Operations.ipynb
# 11-03-2026  09:11             2,329 Functions.ipynb
# 13-03-2026  21:00             7,517 ListMethods.ipynb
# 09-03-2026  09:36            13,633 ListOperations.ipynb
# ...
