# %%
# Dictionary = Its is collection of objects that store in key:value pair.
# Dictionary can be declare using {}
# Dictionary can be unordered and mutable and repetition not allowed

# Create a dictionary

student_info = {
    "student_name":"Pratik Honmane",
    "student_education":"BE",
    "student_mobile":7517330553,
    "student_hobbies":["Drawing","Making Rangoli","Excercising","Running"],
}

print(student_info)
# Out:
# {'student_name': 'Pratik Honmane', 'student_education': 'BE', 'student_mobile': 7517330553, 'student_hobbies': ['Drawing', 'Making Rangoli', 'Excercising', 'Running']}

# %%
# Access Dictionary Item using keys

student_info['student_hobbies']
# Out:
# ['Drawing', 'Making Rangoli', 'Excercising', 'Running']

# %%
student_info['student_name']
# Out:
# 'Pratik Honmane'

# %%
# If I want to access Excercising value from student_hobbies key
print(student_info['student_hobbies'][2])
# Out:
# Excercising

# %%
# Length of Dictionary
len(student_info)
# Out:
# 4

# %%
# data type
print(type(student_info))
# Out:
# <class 'dict'>

# %%
# Add object in the dictionary
student_info.update({"student_dob":"30/09/2001"})

# %%
print(student_info)
# Out:
# {'student_name': 'Pratik Honmane', 'student_education': 'BE', 'student_mobile': 7517330553, 'student_hobbies': ['Drawing', 'Making Rangoli', 'Excercising', 'Running'], 'student_dob': '30/09/2001'}

# %%
# Remove object from the dictionary
student_info.pop('student_dob')
# Out:
# '30/09/2001'

# %%
print(student_info)
# Out:
# {'student_name': 'Pratik Honmane', 'student_education': 'BE', 'student_mobile': 7517330553, 'student_hobbies': ['Drawing', 'Making Rangoli', 'Excercising', 'Running'], 0: 'Akash Honmane'}

# %%
# Adding item in the dictionary
student_info[0] = "Akash Honmane"

# %%
print(student_info)
# Out:
# {'student_name': 'Pratik Honmane', 'student_education': 'BE', 'student_mobile': 7517330553, 'student_hobbies': ['Drawing', 'Making Rangoli', 'Excercising', 'Running'], 0: 'Akash Honmane'}

# %%
len(student_info)
# Out:
# 5

# %%
print(student_info)
# Out:
# {'student_name': 'Pratik Honmane', 'student_education': 'BE', 'student_mobile': 7517330553, 'student_hobbies': ['Drawing', 'Making Rangoli', 'Excercising', 'Running'], 0: 'Akash Honmane'}

# %%
student_info.pop(0) # Pass the argument as a key
# Out:
# 'Akash Honmane'

# %%
print(student_info)
# Out:
# {'student_name': 'Pratik Honmane', 'student_education': 'BE', 'student_mobile': 7517330553, 'student_hobbies': ['Drawing', 'Making Rangoli', 'Excercising', 'Running']}

# %%
# Updating the record using index
student_info['student_name'] = "Akash Honmane"

# %%
print(student_info)
# Out:
# {'student_name': 'Akash Honmane', 'student_education': 'BE', 'student_mobile': 7517330553, 'student_hobbies': ['Drawing', 'Making Rangoli', 'Excercising', 'Running']}

# %%
# Another dictionary
my_dict = {
    'student_dob':'30/09/2001',
    'student_height':170
}


my_dict1 = student_info.copy()
print(my_dict1)
# Out:
# {'student_name': 'Akash Honmane', 'student_education': 'BE', 'student_mobile': 7517330553, 'student_hobbies': ['Drawing', 'Making Rangoli', 'Excercising', 'Running']}

# %%
# Get all keys using keys() function
print(student_info.keys())
# Out:
# dict_keys(['student_name', 'student_education', 'student_mobile', 'student_hobbies'])

# %%
# Get all values using values() function
print(student_info.values())
# Out:
# dict_values(['Akash Honmane', 'BE', 7517330553, ['Drawing', 'Making Rangoli', 'Excercising', 'Running']])

# %%
# Get all items using items() function = print both keys and values
print(student_info.items())
# Out:
# dict_items([('student_name', 'Akash Honmane'), ('student_education', 'BE'), ('student_mobile', 7517330553), ('student_hobbies', ['Drawing', 'Making Rangoli', 'Excercising', 'Running'])])
