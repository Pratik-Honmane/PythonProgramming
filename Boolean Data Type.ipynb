# %%
# Boolean Data Type = have only two values i.e. True and False
# Mostly used in the conditional statement

True
# Out:
# True

# %%
False
# Out:
# False

# %%
5 == 5
# Out:
# True

# %%
5 == '5'  # It check data with data type
# Out:
# False

# %%
5 < 3
# Out:
# False

# %%
3 < 5
# Out:
# True

# %%
5 != 6
# Out:
# True

# %%
# None Type = define with None value
# return type is NoneType

a = None
print(a)
# Out:
# None

# %%
type(a)
# Out:
# NoneType
